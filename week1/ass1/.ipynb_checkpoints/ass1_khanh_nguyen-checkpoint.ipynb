# %% [markdown]
# **Assignment 1 - Khanh Nguyen**
# ===========================

# %%
from __future__ import print_function
import pandas as pd
import numpy as np

# %%
df_master_song_list = pd.read_json('MasterSongList.json')
df_master_song_list.head()
# Out:
#                                       _id                  album  \
# 0  {u'$oid': u'52fdfb440b9398049f3d7a8c'}  Gangnam Style (강남스타일)
# 1  {u'$oid': u'52fdfb3d0b9398049f3cbc8e'}                 Native
# 2  {u'$oid': u'52fdfb420b9398049f3d3ea5'}      Party Rock Anthem
# 3  {u'$oid': u'52fdfb410b9398049f3d1eac'}              Gentleman
# 4  {u'$oid': u'52fdfb400b9398049f3d0b19'}           On The Floor
#
#            artist                                     audio_features  \
# 0             PSY  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1     OneRepublic  [6, 0.745704, 0.119955, 100.008, 0.046255, 0.0...
# 2           LMFAO  [5, 0.709932, 0.231455, 130.03, 0.121741, 0.03...
# 3             PSY  [3, 0.705822, 0.053292, 126.009, 0.126016, 0.0...
# 4  Jennifer Lopez  [3, 0.741757, 0.072774, 129.985, 0.051255, 0.0...
#
#                                         context  decades       genres  \
# 0                                    [work out]       []        [pop]
# 1                                   [energetic]   [2012]        [pop]
# 2  [energetic, energetic, energetic, energetic]       []           []
# 3    [party, party, party, party, party, party]  [2010s]      [dance]
# 4                                [party, party]  [2000s]  [reggaeton]
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [party, rock, yeah, woo, let, s, go, party, ro...
# 3  [alagamun, lan, weh, wakun, heya, hanun, gon, ...
# 4  [j, lo, the, other, side, out, my, mine, it, s...
#
#                              moods                   name new_context  \
# 0        [energetic, motivational]  Gangnam Style (강남스타일)    work out
# 1                          [happy]         Counting Stars   energetic
# 2      [happy, celebratory, rowdy]      Party Rock Anthem   housework
# 3  [happy, energetic, celebratory]              Gentleman   energetic
# 4                      [energetic]           On The Floor    work out
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/049/414/127/...       52379.0
# 3  http://images.musicnet.com/albums/082/950/461/...       12353.0
# 4  http://images.musicnet.com/albums/050/131/765/...       29502.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2  [energy boost, pleasing a crowd, housework, dr...  KQ6zr6kCPj8   971128436
# 3  [driving in the left lane, energy boost, girls...  ASO_zypdnsQ   892096527
# 4         [working out: cardio, dance party: sweaty]  t4H_Zoh7G5A   873285189

# %%
df_master_song_list['genres'] = df_master_song_list['genres'].apply(' '.join)
df_master_song_list['genres'] = df_master_song_list['genres'].map(lambda x: x.split(':')[0] if len(x) > 0 else x)
# df_master_song_list.head()

# %%
# df_master_song_list['genres'].unique()
# Out:
# array([u'pop', '', u'dance', u'reggaeton', u'r&b', u'latin', u'rock',
#        u'singer-songwriter', u'rap', u'international/world', u'indie',
#        u'jazz', u'country', u'folk', u'reggae & ska', u"children's",
#        u'electronica', u'hawaiian ', u'funk', u'blues & blues rock',
#        u'showtunes', u'christian', u"dubstep & drum 'n' bass",
#        u'classical', u'oldies', u'easy listening', u'film scores',
#        u'nature sounds', u"int'l", u'bluegrass'], dtype=object)

# %%
def filter_genres(df, arg):
    if len(arg) <= 0:
        return df.copy()
    filtered_result = pd.Series(np.zeros(df.shape[0], dtype=bool))
    for genre in arg:
        filtered = df['genres'] == genre
        filtered_result |= filtered
    return df[filtered_result].copy()
df_master_song_filtered = filter_genres(df_master_song_list, ['rap', 'country'])
df_master_song_filtered.groupby('genres').count()
# Out:
#           _id  album  artist  audio_features  context  decades  \
# genres
# country  1284   1284    1284            1284     1284     1284
# rap      2931   2931    2931            2931     2931     2931
#
#          lyrics_features  moods  name  new_context  picture  recording_id  \
# genres
# country             1284   1284  1284          869     1284          1116
# rap                 2931   2931  2931         2535     2931          2603
#
#          sub_context  yt_id  yt_views
# genres
# country          869   1284      1284
# rap             2535   2931      2931

# %%
# Remove nan row
null_audio_features = df_master_song_filtered[df_master_song_filtered.audio_features.str.len() == 0]
df_master_song_filtered.drop(null_audio_features.index, inplace=True)

# %%
def balance_classes(df, column):
    classes = df[column].unique()
    count_classes = df[column].value_counts()
    min_class = count_classes.idxmin()
    for _class in count_classes.index.values:
        if _class == min_class:
            continue
        num_of_drop_rows = count_classes[_class] - count_classes[min_class]
        selected_remove_row = df[df[column] == _class].sample(n=num_of_drop_rows)
        df.drop(selected_remove_row.index, axis=0, inplace=True)
    return df

df_master_song_filtered_bal = balance_classes(df_master_song_filtered, 'genres')
df_master_song_filtered_bal.reset_index(inplace=True, drop=True)
df_master_song_filtered_bal['genres'].value_counts()
# Out:
# country    1075
# rap        1075
# Name: genres, dtype: int64

# %%
feature_col_names = [
                        'key',
                        'energy',
                        'liveliness',
                        'tempo',
                        'speechiness',
                        'acousticness',
                        'instrumentalness',
                        'time_signature',
                        'duration',
                        'loudness',
                        'valence',
                        'danceability',
                        'mode',
                        'time_signature_confidence',
                        'tempo_confidence',
                        'key_confidence',
                        'mode_confidence'
                    ]
df_features = pd.DataFrame(df_master_song_filtered_bal['audio_features'].tolist(), columns=feature_col_names)
drop_column = [
#                         'key',
#                         'energy',
                        'liveliness',
#                         'tempo',
#                         'speechiness',
#                         'acousticness',
#                         'instrumentalness',
                        'time_signature',
                        'duration',
#                         'loudness',
#                         'valence',
#                         'danceability',
#                         'mode',
#                         'time_signature_confidence',
#                         'tempo_confidence',
#                         'key_confidence',
#                         'mode_confidence'
                    ]
df_features_selected = df_features.drop(drop_column, axis=1)
df_features_selected.head(10)

df_inspec = pd.concat((df_master_song_filtered_bal['genres'], df_features_selected), axis=1)
df_inspec.groupby('genres').mean()
# df_master_song_filtered_bal.head()
# df_features_selected = df_features
# Out:
#               key    energy       tempo  speechiness  acousticness  \
# genres
# country  4.893953  0.538677  123.245481     0.050879      0.462542
# rap      5.607442  0.688475  111.094647     0.222946      0.146763
#
#          instrumentalness    loudness   valence  danceability      mode  \
# genres
# country          0.033939  196.841046 -9.521884      0.624959  0.573238
# rap              0.081950  251.912813 -7.855394      0.596229  0.706018
#
#          time_signature_confidence  tempo_confidence  key_confidence  \
# genres
# country                   0.646104          0.608213        0.488153
# rap                       0.436059          0.424272        0.457249
#
#          mode_confidence
# genres
# country         0.852580
# rap             0.954386

# %%
df_features_selected['speechiness'].fillna(df_features_selected['speechiness'].median(), inplace=True)
# for column in df_features.columns.values:
#     print(column)
#     print(df_features[column].isnull().unique())

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
std_scaler = StandardScaler()
df_features_scaled = std_scaler.fit_transform(df_features_selected)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
def knn_music(X, y, k):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_predict = knn.predict(X_test)
    knn_report = classification_report(y_test, y_predict)
    knn_matrix = confusion_matrix(y_test, y_predict)
    return (knn_report, knn_matrix)
knn_report, knn_matrix = knn_music(df_features_scaled, df_master_song_filtered_bal['genres'], 80)
print(knn_report)
print(knn_matrix)
# Out:
#              precision    recall  f1-score   support
#
#     country       0.92      0.92      0.92       319
#         rap       0.93      0.92      0.92       326
#
# avg / total       0.92      0.92      0.92       645
#
# [[295  24]
#  [ 25 301]]

# %%
from sklearn.cross_validation import cross_val_score
def knn_cross_val_music(X, y, k):
    knn = KNeighborsClassifier(n_neighbors=k)
    cross_score = cross_val_score(knn, X=X, y=y, cv=10)
    return cross_score
cross_score = knn_cross_val_music(df_features_scaled, df_master_song_filtered_bal['genres'], 80)
print(cross_score)
print(cross_score.mean())
# Out:
# [ 0.90277778  0.94907407  0.9212963   0.91666667  0.93055556  0.92523364
#   0.94392523  0.94859813  0.92990654  0.91588785]
# 0.928392177224

# %%
k_range = range(5, 100, 5)
k_cross_scores = []
for k in k_range:
    cross_score = knn_cross_val_music(df_features_scaled, df_master_song_filtered_bal['genres'], k)
    k_cross_scores.append(cross_score.mean())
k_cross_scores
# Out:
# [0.92887244721356876,
#  0.92607303565247479,
#  0.92746192454136378,
#  0.92653599861543778,
#  0.92700761509172724,
#  0.92515143648321219,
#  0.92654032537210118,
#  0.92792921426098984,
#  0.92700761509172713,
#  0.92653599861543778,
#  0.92839217722395284,
#  0.92513412945655937,
#  0.92651869158878486,
#  0.92558411214953262,
#  0.92792488750432667,
#  0.92839217722395284,
#  0.92932675666320519,
#  0.92699030806507443,
#  0.92699463482173761]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(k_range, k_cross_scores, 'r-')
plt.xlabel('k-nn')
plt.ylabel('score')
plt.show()
